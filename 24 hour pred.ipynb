# %%
y_test_real = np.expm1(y_test)
pred_test_real = np.expm1(pred_test)

# %%
print("MAE :", mean_absolute_error(y_test, pred_test))
print("RMSE:", np.sqrt(mean_squared_error(y_test, pred_test)))
print("R2  :", r2_score(y_test, pred_test))
# Out:
# MAE : 12.796659136715709
# RMSE: 29.20302628754916
# R2  : 0.9041028131597624

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df["datetime"].iloc[split:],
    y_test.values,
    label="Observed PM2.5",
    linewidth=2
)

plt.plot(
    df["datetime"].iloc[split:],
    pred_test,
    linestyle="--",
    linewidth=2,
    label="Predicted PM2.5"
)

plt.xlabel("Time")
plt.ylabel("PM2.5 (µg/m³)")
plt.title("Observed vs Predicted PM2.5 (Test Data)")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    df["datetime"].iloc[-48:],
    df["pm2.5"].iloc[-48:],
    linewidth=2,
    label="Observed PM2.5 (Past)"
)

plt.plot(
    forecast_df["datetime"],
    forecast_df["predicted_pm2.5"],
    linestyle="--",
    marker="o",
    linewidth=2,
    label="Predicted PM2.5 (Next 24h)"
)

plt.axvline(
    df["datetime"].iloc[-1],
    linestyle=":",
    linewidth=1.5,
    label="Forecast Start"
)

plt.xlabel("Time")
plt.ylabel("PM2.5 (µg/m³)")
plt.title("24-Hour PM2.5 Forecast (Random Forest)")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
